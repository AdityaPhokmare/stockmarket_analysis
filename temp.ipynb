# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\adity\Desktop\Git  Projects\stockmarket_analysis\Stock_Info.csv")

# %%
df[df["Country"].isna()]
# Out:
#      Symbol                                               Name Last Sale  \
# 3      AACT  Ares Acquisition Corporation II Class A Ordina...   $10.921
# 6       AAM  AA Mission Acquisition Corp. Class A Ordinary ...    $10.07
# 214     AIO  Virtus Artificial Intelligence & Technology Op...    $25.33
# 236     AKA           a.k.a. Brands Holding Corp. Common Stock    $20.17
# 317    AMBI  Ambipar Emergency Response Class A Ordinary Sh...     $5.10
# ...     ...                                                ...       ...
# 6939   ZDGE                   Zedge Inc. Class B Common Stock      $2.79
# 6948    ZGN             Ermenegildo Zegna N.V. Ordinary Shares     $8.51
# 6951    ZIM  ZIM Integrated Shipping Services Ltd. Ordinary...   $19.925
# 6961    ZKH  ZKH Group Limited American Depositary Shares e...     $3.85
# 6967   ZONE      CleanCore Solutions Inc. Class B Common Stock     $1.30
#
#       Net Change % Change    Market Cap Country  IPO Year   Volume  \
# ...

# %%
# Out:
#       Symbol   Name  Last Sale  Net Change  % Change  Market Cap  Country  \
# 0      False  False      False       False     False       False    False
# 1      False  False      False       False     False       False    False
# 2      False  False      False       False     False       False    False
# 4      False  False      False       False     False       False    False
# 5      False  False      False       False     False       False    False
# ...      ...    ...        ...         ...       ...         ...      ...
# 6980   False  False      False       False     False       False    False
# 6981   False  False      False       False     False       False    False
# 6982   False  False      False       False     False       False    False
# 6983   False  False      False       False     False       False    False
# 6984   False  False      False       False     False       False    False
#
#       IPO Year  Volume  Sector  Industry
# ...

# %%
df.set_index("Name", inplace = True)
df.to_dict()
# Out:
# {'Symbol': {'Agilent Technologies Inc. Common Stock': 'A',
#   'Alcoa Corporation Common Stock ': 'AA',
#   'ATA Creativity Global American Depositary Shares': 'AACG',
#   'Ares Acquisition Corporation II Class A Ordinary Shares': 'AACT',
#   'Aadi Bioscience Inc. Common Stock': 'AADI',
#   'American Airlines Group Inc. Common Stock': 'AAL',
#   'AA Mission Acquisition Corp. Class A Ordinary Shares': 'AAM',
#   'Atlantic American Corporation Common Stock': 'AAME',
#   'Applied Optoelectronics Inc. Common Stock': 'AAOI',
#   'AAON Inc. Common Stock': 'AAON',
#   'Advance Auto Parts Inc.': 'AAP',
#   'Apple Inc. Common Stock': 'AAPL',
#   'American Assets Trust Inc. Common Stock': 'AAT',
#   'AllianceBernstein Holding L.P.  Units': 'AB',
#   'American Battery Technology Company Common Stock': 'ABAT',
#   'AbbVie Inc. Common Stock': 'ABBV',
#   'Ameris Bancorp Common Stock': 'ABCB',
#   'AbCellera Biologics Inc. Common Shares': 'ABCL',
# ...

# %%
df["Symbol"].to_dict()
# Out:
# {'Agilent Technologies Inc. Common Stock': 'A',
#  'Alcoa Corporation Common Stock ': 'AA',
#  'ATA Creativity Global American Depositary Shares': 'AACG',
#  'Ares Acquisition Corporation II Class A Ordinary Shares': 'AACT',
#  'Aadi Bioscience Inc. Common Stock': 'AADI',
#  'American Airlines Group Inc. Common Stock': 'AAL',
#  'AA Mission Acquisition Corp. Class A Ordinary Shares': 'AAM',
#  'Atlantic American Corporation Common Stock': 'AAME',
#  'Applied Optoelectronics Inc. Common Stock': 'AAOI',
#  'AAON Inc. Common Stock': 'AAON',
#  'Advance Auto Parts Inc.': 'AAP',
#  'Apple Inc. Common Stock': 'AAPL',
#  'American Assets Trust Inc. Common Stock': 'AAT',
#  'AllianceBernstein Holding L.P.  Units': 'AB',
#  'American Battery Technology Company Common Stock': 'ABAT',
#  'AbbVie Inc. Common Stock': 'ABBV',
#  'Ameris Bancorp Common Stock': 'ABCB',
#  'AbCellera Biologics Inc. Common Shares': 'ABCL',
#  'Abeona Therapeutics Inc. Common Stock': 'ABEO',
# ...
